# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
import matplotlib 

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import os

# %% [markdown]
# # This notebook checks that GPT maintains the particle ID number
# ---

# %% [markdown]
# # Make an input dist with two particles and assign id = [25, 75]:

# %%
from beamphysics import single_particle
pg = single_particle(x=-0.001, pz=10000) + single_particle(x=+0.001, pz=10000)
pg.assign_id()
pg.id = np.array([25, 75])
print(pg)
# Out:
# ParticleGroup with 2 particles with total charge 2.0 C

# %%
from gpt import GPT
from gpt.template import basic_template

G = GPT(input_file=basic_template(), initial_particles=pg)
G.run()

assert len(G.tout)==50, 'Inconsistent number of touts'

known_values = {'x':  np.array([-0.001, 0.001]),  
                'pz': np.array([10000, 10000]),
                'id': np.array([25.0, 75.0])}

for tout in G.tout:
    for key, values in known_values.items():
        assert np.all(np.isclose(tout[key], values)), 'Particle trajectories are not consistent'

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for ID in pg.id:
    
    tid = G.trajectory(ID, data_type='tout')
    if(tid):
        ax.plot(tid['x']*1000, tid['y']*1000, tid['z'], zdir='x')
        print(f'particle id = {ID},', f'mean x pos = {tid["x"].mean()}')

ax.set_xlabel('z (m)');
ax.set_ylabel('x (mm)');
ax.set_zlabel('y (mm)');
# Out:
# particle id = 25, mean x pos = -0.001
# particle id = 75, mean x pos = 0.001

# %%
print(G.tout[-1]['id'])
# Out:
# [25. 75.]

# %%
os.system('rm -rf gpt.temp.in');
