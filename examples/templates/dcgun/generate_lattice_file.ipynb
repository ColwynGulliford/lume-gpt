# %% [markdown]
# # Generate DC Gun Lattife File
# ---

# %%
from gpt import GPT
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
G = GPT('gpt.in')

# %%
G.lattice.plot_floor()
# Out:
# <Axes: xlabel='z (m)', ylabel='x (m)'>
